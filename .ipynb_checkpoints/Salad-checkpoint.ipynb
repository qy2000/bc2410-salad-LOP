# %% [markdown]
# # Problem 1: Too much choices given to Salad Stop's customers
#
# #### Summary:
# Salad Stop currently provides a wide variety of ingredients, dressings and toppings for their customers to choose from. As a result, this creates a problem whereby too much choices are given to their customers which is a potential turn-off to them. As a solution, we created a "Salad Suggester" which is essentially a linear optimizer which generates a salad which maximizes profits given a set of constraints/requirements set by Salad Stop's customer.
#
# #### References:
# https://papers.ssrn.com/sol3/papers.cfm?abstract_id=3493371
# https://www.stern.nyu.edu/sites/default/files/assets/documents/Anisha%20Patel_Thesis_Honors%202014.pdf

# %% [markdown]
# ## Descriptive Analytics
#
# In this section, we will prove the relationship between choices and how it influences the purchase probability of a consumer. We will artificially generate a fake dataset which will be a simplified version of the dataset used in the "Too Little or Too Much Seller Assortment: The Effects on Buyers’ Purchase Probabilities in a Food Sharing Platform" research paper.

# %%
"""
Import Libraries
"""

import pandas as pd
import numpy as np
import math
import datetime
import seaborn as sb
import matplotlib.pyplot as plt
import random
from faker import Faker
import os  
import plotly.express as px
import matplotlib.pyplot as plt
from matplotlib import pyplot
SEED = 0
Faker.seed(SEED)
np.random.seed(SEED)
random.seed(SEED)

# %%
"""
Use python's Faker libary to artificially generate fake data.
"""
fake = Faker()

"""
Fake Restaurant Names obtained from https://businessnamegenerator.com/restaurants-business-name-generator-ideas/
"""
restaurant_names = ["Bistro Bazaar","Bistro Captain","Bistroporium","Cuisine Street","Cuisine Wave","Deli Divine","Deli Feast","Eatery Hotspot","Eateryworks","Feast Lounge","Feast Palace","Grub Chef","Grub lord","Kitchen Sensation","Kitchen Takeout","Menu Feed","Menu Gusto","Munchies","Munch Grill","Munchtastic","Island Grill","Flavoroso","Green Curry","El Pirata Porch","Sweet Escape","Salty Squid","Bangalore Spices","Pancake World","Veganic Corner","Masala","Grassfed Grill","Greenanic Smoothies","Freddy’s Stove","Grandma’s Sweets","Spicella Spanish Kitchen","Xin Chao Vietnamese Restaurant","Paterro's Kitchen","Mediterra Seafood","Street Deli","Whispering Bamboo"]

"""
Randomly populate number of menu items for each of the restaurant
"""
restaurant_number_of_items = [random.randint(1, 40) for _ in range(len(restaurant_names))]

"""
Weighted function which returns whether there was a purchase based on the number of items on the menu.
"""    
def random_there_was_a_purchase_generator(num_of_items_on_menu):
    if 1 <= num_of_items_on_menu <= 3:
        return np.random.choice([0, 1], 1, p=[0.95, 0.05])[0]
    
    if 4 <= num_of_items_on_menu <= 5:
        return np.random.choice([0, 1], 1, p=[0.9, 0.1])[0]
    
    elif 6 <= num_of_items_on_menu <= 8:
        return np.random.choice([0, 1], 1, p=[0.05, 0.95])[0]
    
    elif 9 <= num_of_items_on_menu <= 11:
        return np.random.choice([0, 1], 1, p=[0.05, 0.95])[0]
    
    elif 12 <= num_of_items_on_menu <= 14:
        return np.random.choice([0, 1], 1, p=[0.9, 0.1])[0]
    
    elif 15 <= num_of_items_on_menu <= 17:
        return np.random.choice([0, 1], 1, p=[0.9, 0.1])[0]
    
    elif 18 <= num_of_items_on_menu <= 20:
        return np.random.choice([0, 1], 1, p=[0.9, 0.1])[0]
    
    elif 21 <= num_of_items_on_menu <= 25:
        return np.random.choice([0, 1], 1, p=[0.95, 0.05])[0]
    
    elif 26 <= num_of_items_on_menu <= 30:
        return np.random.choice([0, 1], 1, p=[0.95, 0.05])[0]
    
    elif 31 <= num_of_items_on_menu <= 40:
        return np.random.choice([0, 1], 1, p=[0.9995, 0.0005])[0]
    
    else:
        return np.random.choice([0, 1], 1, p=[0.9995, 0.0005])[0]

# %%
"""
Creating a fake dataset based on our faked data and variables
"""
def generate_fake_dataset():

    res_name = restaurant_names[random.randint(0, 39)]
    res_num_items = restaurant_number_of_items[restaurant_names.index(res_name)]
    is_purchase = random_there_was_a_purchase_generator(res_num_items)
    
    return {
        "UUID": "ID-{}".format(fake.credit_card_number()[1:10]),
        "Name": fake.name(),
        "Restaurant Visited": res_name,
        "Number of items on menu": res_num_items,
        "Purchase": is_purchase
    }
        

df = pd.DataFrame([generate_fake_dataset() for _ in range(1000)])
df.to_csv('faked_purchase_dataset.csv')  
df
# Out:
#              UUID               Name              Restaurant Visited  \
# 0    ID-504876475      Brandon Lloyd  Xin Chao Vietnamese Restaurant
# 1    ID-131411578         Susan Levy                   Bistro Bazaar
# 2    ID-884080160  Frederick Harrell                     Deli Divine
# 3    ID-328711587    Michelle Kelley                     Salty Squid
# 4    ID-131989471  Clinton Underwood                   Bistro Bazaar
# ..            ...                ...                             ...
# 995  ID-375563356      Kevin Barajas                    Island Grill
# 996  ID-011732912    Kathleen Fowler                 El Pirata Porch
# 997  ID-131062236    Jennifer Becker               Mediterra Seafood
# 998  ID-793828318     Thomas Ramirez                  Bistro Captain
# 999  ID-704671101       Kyle Goodwin                     Eateryworks
#
#      Number of items on menu  Purchase
# 0                         31         0
# 1                         25         0
# 2                         32         0
# 3                         22         0
# 4                         25         0
# ..                       ...       ...
# 995                       39         0
# 996                        7         1
# 997                       34         0
# 998                       27         0
# 999                       31         0
#
# [1000 rows x 5 columns]

# %%
"""
Import fake dataset to create visualisations
"""
fake_customer_data = pd.read_csv('faked_purchase_dataset.csv')
fake_customer_data = pd.DataFrame(fake_customer_data.groupby('Number of items on menu')['Purchase'].apply(lambda x: x[x == 1].count()))
fake_customer_data
# Out:
#                          Purchase
# Number of items on menu
# 3                               1
# 4                               2
# 5                               2
# 7                              70
# 9                              45
# 10                             24
# 14                              7
# 17                             10
# 19                              4
# 20                             11
# 21                              1
# 22                              1
# 23                              1
# 25                              2
# 26                              0
# 27                              4
# 28                              0
# 29                              1
# 31                              0
# 32                              0
# 33                              0
# 34                              0
# 35                              0
# 36                              0
# 38                              0
# 39                              0
# 40                              0

# %%
"""
From the following graph, we observe that restaurants with low number of items on their menu encounter
lower number of purchases. On the other end of the extreme, restaurants with high number of items of their
menu encounter also encounter low number of purchases. The optimal number of items on menu that receives
highest number of purchases seem to be 7 items.
"""

"""
Plotly Version
"""

# fig = px.bar(fake_customer_data, height=300, labels={'value':'Number of purchases in a day'})
# fig.show()

"""
Matplotlib Version
"""

fig = plt.figure()
fig.set_size_inches(20, 5)
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Number of purchases in a day')
ax.set_xlabel('Number of items found in menu')
langs = fake_customer_data.index
students = fake_customer_data["Purchase"]
ax.bar(langs,students)
plt.show()

# %% [markdown]
# ## Predictive Analytics
#
# In this section, We will build a model based off our artificially generated dataset to be able to predict the purchase probability based on number of options given to consumers.

# %%
"""
Import Libaries
"""

from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
import graphviz

# %%
"""
Import dataset and prepare training/testing data
"""

customer_data = pd.read_csv('faked_purchase_dataset.csv')
y = pd.DataFrame(customer_data["Purchase"])
x = pd.DataFrame(customer_data[["Number of items on menu"]])

x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=SEED, test_size = 0.1)

# %%
"""
Train and fit decision tree (CART)
"""

dectreex1 = DecisionTreeClassifier(max_depth = 3)
dectreex1.fit(x_train, y_train)

treedot = export_graphviz(dectreex1, feature_names = x_train.columns, class_names = True, out_file = None, filled = True, rounded = True, special_characters = True)      
graphviz.Source(treedot)

# %%
"""
Evaluate performance of Decision Tree using classification accuracy
"""

y_train_pred = dectreex1.predict(x_train)
y_test_pred = dectreex1.predict(x_test)

print("Goodness of Fit of Model \tTrain Dataset")
print("Classification Accuracy \t:", dectreex1.score(x_train, y_train))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("Classification Accuracy \t:", dectreex1.score(x_test, y_test))
print()
# Out:
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9477777777777778
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.94

# %%
def was_there_a_purchase(value):
    if value == 1: return "will"
    else: return "will not"

NUMBER_OF_ITEMS_ON_MENU = 1
salad_stop_prediction_arr = np.array([[NUMBER_OF_ITEMS_ON_MENU]])
salad_stop_prediction_df = pd.DataFrame(salad_stop_prediction_arr, columns = ['Number of items on menu'])
salad_stop_prediction = dectreex1.predict(salad_stop_prediction_df)
print("Particular customer {} have made a purchase at a restautant with {} items!".format(was_there_a_purchase(salad_stop_prediction[0]), NUMBER_OF_ITEMS_ON_MENU))

NUMBER_OF_ITEMS_ON_MENU = 8
salad_stop_prediction_arr = np.array([[NUMBER_OF_ITEMS_ON_MENU]])
salad_stop_prediction_df = pd.DataFrame(salad_stop_prediction_arr, columns = ['Number of items on menu'])
salad_stop_prediction = dectreex1.predict(salad_stop_prediction_df)
print("Particular customer {} have made a purchase at a restautant with {} items!".format(was_there_a_purchase(salad_stop_prediction[0]), NUMBER_OF_ITEMS_ON_MENU))

NUMBER_OF_ITEMS_ON_MENU = 30
salad_stop_prediction_arr = np.array([[NUMBER_OF_ITEMS_ON_MENU]])
salad_stop_prediction_df = pd.DataFrame(salad_stop_prediction_arr, columns = ['Number of items on menu'])
salad_stop_prediction = dectreex1.predict(salad_stop_prediction_df)
print("Particular customer {} have made a purchase at a restautant with {} items!".format(was_there_a_purchase(salad_stop_prediction[0]), NUMBER_OF_ITEMS_ON_MENU))

SALAD_STOP = 38
salad_stop_prediction_arr = np.array([[SALAD_STOP]])
salad_stop_prediction_df = pd.DataFrame(salad_stop_prediction_arr, columns = ['Number of items on menu'])
salad_stop_prediction = dectreex1.predict(salad_stop_prediction_df)
print("Particular customer {} have made a purchase at a Salad Stop with {} items!".format(was_there_a_purchase(salad_stop_prediction[0]), SALAD_STOP))
# Out:
# Particular customer will not have made a purchase at a restautant with 1 items!
# Particular customer will have made a purchase at a restautant with 8 items!
# Particular customer will not have made a purchase at a restautant with 30 items!
# Particular customer will not have made a purchase at a Salad Stop with 38 items!

# %% [markdown]
# ## Prescriptive Analytics
#
# In this section, we will propose our solution to help Salad Stop's customer to create a salad based on their
# preference without them having to make any selections while still allowing Salad Stop to profit. Our solution is
# a linear optimization model which aims to suggest a salad based on a customer's preferences or constraints while
# allowing Salad Stop as a business to maximize their profits

# %%
"""
Import Libaries
"""

from rsome import ro
from rsome import grb_solver as grb

# %%
"""
Data Preparation: All information obtained regarding Salad Stop was directly scrapped from their 
website https://www.saladstop.com.sg/
"""

data1 = pd.read_csv('menu.csv')
header1 = data1.columns

print("Shape of dataset: {} rows, {} columns".format(data1.shape[0], data1.shape[1]))
# Out:
# Shape of dataset: 88 rows, 25 columns

# %%
"""
We will be artificially setting the total quantity available of each ingredient and dynamically change it
after every order is generated later on
"""

ORIGINAL_QTY = 5

data1['Total'] = ORIGINAL_QTY
print("Total number of ingredients is {} and should be {}".format(sum(data1['Total']), data1.shape[0] * ORIGINAL_QTY))
# Out:
# Total number of ingredients is 440 and should be 440

# %%
"""
Final dataset we will use
"""

data1.head()
# Out:
#             Ingredient Ingredient_type  Price  Serving_size  COGS  \
# 0  Red & White Cabbage   Standard Base    NaN            90  6.45
# 1              Romaine   Standard Base    NaN           120  3.10
# 2                 Kale    Premium Base    NaN            90  5.00
# 3         Baby Spinach    Premium Base    NaN            90  1.25
# 4       Wholemeal Wrap            Wrap    NaN           100  3.55
#
#    per (g, pcs, unit)  COGS_per_serving  \
# 0              1100.0              0.53
# 1               200.0              1.86
# 2               120.0              3.75
# 3               200.0              0.56
# 4               360.0              0.99
#
#    Adjusted_COGS_per_serving (if needed)  Calories  Carbohydrates  ...  \
# 0                                    NaN        26            3.4  ...
# 1                                   0.86        20            4.0  ...
# 2                                   1.75        32            4.0  ...
# 3                                   1.56        21            3.3  ...
# 4                                    NaN       297           54.8  ...
#
#    Carbon_footprint  Vegan  Vegetarian  Gluten  Dairy  Nuts  Spicy  \
# 0             0.064      1           1       0      0     0      0
# 1             0.033      1           1       0      0     0      0
# 2             0.022      1           1       0      0     0      0
# 3             0.029      1           1       0      0     0      0
# 4             0.180      0           1       0      0     0      0
#
#                                              Sources  Unnamed: 24  Total
# 0  https://omni.fairprice.com.sg/category/fruits-...          NaN      5
# 1  https://omni.fairprice.com.sg/search?query=rom...          NaN      5
# 2  https://omni.fairprice.com.sg/product/vegeponi...          NaN      5
# 3  https://omni.fairprice.com.sg/product/kok-fah-...          NaN      5
# 4  https://www.fairprice.com.sg/product/fairprice...          NaN      5
#
# [5 rows x 26 columns]

# %%
"""
Generate salad based on user's input:

Details on Salad Stop:
Link: https://www.saladstop.com.sg/cyo/
1. Choose either premium base or standard base (standard base includes wrap and grain bowls)
2. Choose 2 dressing
3. Choose 7 standard toppings (even if you chose premium base)
4. Can add as many premium toppings as you want but will have additional charges
"""

def generate_salad(user_input, data_input, ingredient_qty):
    
    try:
    
        '''
        Construct Optimizer.
        '''
        model = ro.Model('Salad selector model')

        '''
        Other variables to be used later:
        n refers to the total number of ingredients offered by salad stop
        '''
        n = len(data_input["ingredient"])

        '''
        Initialize Decision Variables
        x is the selection of an ingredient in the salad (binary variables)
        s is the standard base selection (binary variable)
        t is the premium base selection (binary variable)
        '''
        x = model.dvar(n, vtype='B')
        s = model.dvar((1,), vtype='B')
        t = model.dvar((1,), vtype='B')

        '''
        Create Objective Function: To minimize cost paid by the customer while meeting user input constraints.
        
        This objective function is preferred because the problem stems from the customer side rather than the business side.
        Whereby customers are confused at what to order due to the presence of too many choices. If we are optimizing the choices
        customers should make, then we should minimize the cost of the salad paid by the customer as the customer would want to
        pay as little as possible for their salad.
        '''
        model.min((9.9*s + 11.9*t + sum(x[i]*data_input["price"][i] for i in range(n) if data_input["ingredient_type"][i] in ['Premium Topping'])))

        '''
        Alternative Objective Function: To maximize profit earned by the business while meeting user input constraints.
        '''
        # model.max((9.9*s + 11.9*t + sum(x[i]*data_input["price"][i] for i in range(n) if data_input["ingredient_type"][i] in ['Premium Topping'])) - (sum(x[i]*data_input["cost"][i] for i in range(n))))
        
        '''
        Constraints 1: Optimizer will not select ingredient with 0 quantity left 
        '''
        model.st(sum(x[i] for i in range(n) if ingredient_qty[i] == 0) == 0)

        '''
        Constraints 2: Depending on the base selected, ingredients should be of the same category as the type of base selected
        '''
        model.st(sum(x[i] for i in range(n) if data_input["ingredient_type"][i] in ['Standard Base', 'Wrap', 'Grain Bowl']) == s)
        model.st(sum(x[i] for i in range(n) if data_input["ingredient_type"][i] in ['Premium Base']) == t)

        '''
        Constraints 3: Ensure that either standard base is selected or premium base selected. Cannot be neither selected or both selected
        '''
        model.st(0 <= s <= 1)
        model.st(0 <= t <= 1)
        model.st(s + t == 1)

        '''
        Constraints 4: Ensure that only exactly 7 toppings unless the user wants more will be chosen
        '''
        model.st(sum(x[i] for i in range(n) if data_input["ingredient_type"][i] in ['Standard Topping']) == 7)

        '''
        Constraints 5: Ensure that only exactly 2 dressings unless the user wants more will be chosen
        '''
        model.st(sum(x[i] for i in range(n) if data_input["ingredient_type"][i] in ['Dressing (Asian)', 'Dressing (Western)']) == 2)

        '''
        Constraints 6: Ensure that the selection of ingredients meets nutrition requirements of user
        '''
        nutrition_list = [data_input["calories"], data_input["carbs"], data_input["protein"], data_input["fat"], data_input["sugar"]]
        for j in range(len(nutrition_list)):
            nutri =  nutrition_list[j]
            model.st(user_input["min_nutrition"][j] <= sum(x[i]*nutri[i] for i in range(n)))
            model.st(sum(x[i]*nutri[i] for i in range(n)) <= user_input["max_nutrition"][j])

        '''
        Constraints 7: Ensure that the dietary needs of user is met
        '''
        reqs = [data_input["vegan"], data_input["vegetarian"], data_input["gluten"], data_input["dairy"], data_input["nuts"], data_input["spicy"]]
        for k in range(len(user_input["dietary_req"])):
            req_type = reqs[k]
            if user_input["dietary_req"][k] == 0:
                model.st(sum(x[i] for i in range(n) if req_type[i] == 1) == 0 )

        '''
        Constraints 8: Ensure that the number of premium toppings meet user requirements
        '''
        model.st(sum(x[i] for i in range(n) if data_input["ingredient_type"][i] in ['Premium Topping']) >= user_input["max_num_of_premium_toppings"])

        '''
        Constraints 9: Ensure that the total cost of the salad is within the user's budget
        '''
        model.st((9.9*s + 11.9*t + sum(x[i]*price[i] for i in range(n) if data_input["ingredient_type"][i] in ['Premium Topping'])) <= user_input["budget"])

        '''
        Constraints 10: Ensure that the total cost of the salad is within the user's budget
        '''
        model.st(x >= 0)
        
        '''
        Solve Model and generate results
        '''
        model.solve(grb)
        
        if int(s.get()[0]) == 1:
            base = 9.9
        else:
            base = 11.9

        return x.get(), model.get(), base
    
    except:

        return [], 0, 0

# %%
"""
Set user requirements
"""

user_input = {
    "min_nutrition": np.array([450, 30, 20, 0, 0]), # calories, carbs, protein, fat, sugar
    "max_nutrition": np.array([500, 500, 30, 10, 10]),
    "budget" : 17,
    "max_num_of_premium_toppings": 3,
    "dietary_req": [1,1,1,1,1,1] # vegan, vegetarian, gluten, dairy, nuts, spicy
}

# %%
"""
Set dataset values
"""

data = data1.values

ingredient, ingredient_type, price, cost, calories, carbs, protein, fat, sugar =\
data[:,0], data[:,1], data[:,2], data[:,6], data[:,8], data[:,9], data[:,10], data[:,11], data[:,12]

vegan, vegetarian, gluten, dairy, nuts, spicy =\
data[:,-9], data[:,-8], data[:,-7], data[:,-6], data[:,-5], data[:,-4]

data_input = {
    "ingredient": ingredient,
    "ingredient_type": ingredient_type,
    "price": price,
    "cost": cost,
    "calories": calories,
    "carbs": carbs,
    "protein": protein,
    "fat": fat,
    "sugar": sugar,
    "vegan": vegan,
    "vegetarian": vegetarian,
    "gluten": gluten,
    "dairy": dairy,
    "nuts": nuts,
    "spicy": spicy,
}

# %%
"""
Test our optimizer
"""

total = data[:,-1]
total[-1] = 0

for j in range(1):
    
    response, cost, base = generate_salad(user_input, data_input, total)
    
    if base == 0:
        print("Cannot make a salad... Impossible set of constraints")
    
    else:
        print("\n============== RECEIPT ==============\n")
        print("Purchase: \n")
        total_cost = 0
        total_cost += base
        for i in range(len(response)):
            if response[i] > 0:
                
                index = np.where(data_input["ingredient"] == ingredient[i])[0][0]
                
                print("{}, {}".format(ingredient[i], data_input["ingredient_type"][index]))
                
                if data_input["ingredient_type"][index] == "Premium Topping":
                    total_cost += data_input["price"][index]
                
                if total[i] > 0:
                    total[i] -= 1

        print("\n")
        print("Customer #{}, base price: {}".format(j, base))
        print("Cost of salad: ${}".format(round(total_cost,2)))
        print("Amount of ingredients left: {}".format(sum(total)))
        print("\n=====================================\n")
# Out:
# Restricted license - for non-production use only - expires 2023-10-25
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0070s
#
# ============== RECEIPT ==============
#
# Purchase:
#
# Quinoa, Grain Bowl
# Pea Sprouts, Standard Topping
# Pomelo, Standard Topping
# Soba Noodles, Standard Topping
# Black Beans, Standard Topping
# Broccoli, Standard Topping
# French Beans, Standard Topping
# Beetroot, Standard Topping
# Thai Asparagus, Premium Topping
# Veggie Patty, Premium Topping
# Grilled Tofu, Premium Topping
# Salt & Pepper, Dressing (Western)
# Tabbasco Sauce, Dressing (Western)
#
#
# Customer #0, base price: 9.9
# Cost of salad: $14.4
# Amount of ingredients left: 422
#
# =====================================

# %% [markdown]
# # Problem 2: Optimizing the quantity of ingredients to order
#
# #### Summary:
# We performed A/B testing on our linear model and our flask proof of concept with a size of 100 people consisting of our group's family and friends. We then curated their responses and stored it in the dataset "demand_menu.csv". As
# a result of our solution, we expect drastic changes to the overall demand of salad ingredients to Salad Stop. As a
# result, Salad Stop would need to be able to adjust the quantity of ingredients to be purchased based on the fluctuations in demand. As a result, we propose a long-short term memory neural network to study our time-series dataset "demand_menu.csv". Using this model, we predict and forecast future demand of each ingredient. We will then feed this to our stochastic model created based on historical demand and ingredient statistics (e.g. cost, price, space taken up) which will then optimize the optimal number of ingredients to order and the corresponding expected profits

# %% [markdown]
# ## Descriptive Analytics
#
# In this section, we will perform data visualisations to observe the trends of different quantities of each ingredient being ordered at salad stop at a particular store in a particular day

# %% [markdown]
# ## Predictive Analytics
#
# In this section, from our previous dataset, we will build a model to be able to forecast future demands of each ingredient to be used later on for our stochastic model.

# %%
"""
Import Libraries
"""

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras.models import Sequential, load_model, save_model
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error
import matplotlib.pyplot as plt
from matplotlib import pyplot

# %%
"""
Data preparation
"""

Demand_data = pd.read_csv("demand_menu_2.csv")
d = Demand_data.set_index('Date').T
scaler = MinMaxScaler(feature_range=(0,1))
d = scaler.fit_transform(d)

# %%
"""
Training Data, Testing Data, and Validation Data

Ratios:
- Training:Testing -> 7:3
- Validation: Training -> 3:10
"""

train_size = int(int(len(d)) * 0.7)
test_size = len(d) - train_size
v_train_size = int(train_size * 0.7)
v_validation_size = train_size - v_train_size

train, validation, test = d[0:v_train_size,:], d[v_train_size:train_size,:], d[train_size:len(d),:]

# %%
"""
Generation of timeseries dataset with lookbacks

For more information on lookback period in time series data preparation:
https://towardsdatascience.com/one-step-predictions-with-lstm-forecasting-hotel-revenues-c9ef0d3ef2df
"""

def create_dataset(dataset, look_back=1):
    dataX, dataY = [], []
    for i in range(len(dataset) - look_back):
        a = dataset[i:(i + look_back), 0]
        dataX.append(a)
        dataY.append(dataset[i + look_back, 0])
    return np.array(dataX), np.array(dataY)

# %%
"""
Actually generating proper datasets with lookbackups with the our function
"""

LOOK_BACK_PERIOD = 10

trainX, trainY = create_dataset(train, LOOK_BACK_PERIOD)
valX, valY = create_dataset(validation, LOOK_BACK_PERIOD)
testX, testY = create_dataset(test, LOOK_BACK_PERIOD)

# %%
"""
Reshaping our datasets to fit our LSTM neural network
"""

trainX = np.reshape(trainX, (trainX.shape[0], 1, trainX.shape[1]))
testX = np.reshape(testX, (testX.shape[0], 1, testX.shape[1]))
valX = np.reshape(valX, (valX.shape[0], 1, valX.shape[1]))

# %%
"""
Constructing our LSTM neural network
"""

model = Sequential()
model.add(LSTM(100, input_shape=(trainX.shape[1], trainX.shape[2])))
model.add(Dense(1))
model.compile(loss='mae', optimizer='adam')
history = model.fit(trainX, trainY, epochs=200, batch_size=10, validation_data=(valX, valY), shuffle=False)
# Out:
# Epoch 1/200
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fb225c66e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_train_function.<locals>.train_function at 0x7fb225c66e60> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 1/2 [==============>...............] - ETA: 6s - loss: 0.0846WARNING:tensorflow:AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fb2267a9f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_test_function.<locals>.test_function at 0x7fb2267a9f80> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# 2/2 [==============================] - 7s 765ms/step - loss: 0.1428 - val_loss: 0.3244
# Epoch 2/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1401 - val_loss: 0.3190
# Epoch 3/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1379 - val_loss: 0.3170
# Epoch 4/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1355 - val_loss: 0.3175
# Epoch 5/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1343 - val_loss: 0.3254
# Epoch 6/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1335 - val_loss: 0.3265
# Epoch 7/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1327 - val_loss: 0.3222
# Epoch 8/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1325 - val_loss: 0.3183
# Epoch 9/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1326 - val_loss: 0.3176
# Epoch 10/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1320 - val_loss: 0.3192
# Epoch 11/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1314 - val_loss: 0.3198
# Epoch 12/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1312 - val_loss: 0.3178
# Epoch 13/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1304 - val_loss: 0.3139
# Epoch 14/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1300 - val_loss: 0.3112
# Epoch 15/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1299 - val_loss: 0.3119
# Epoch 16/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1295 - val_loss: 0.3129
# Epoch 17/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1291 - val_loss: 0.3132
# Epoch 18/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1286 - val_loss: 0.3118
# Epoch 19/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1284 - val_loss: 0.3113
# Epoch 20/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1280 - val_loss: 0.3124
# Epoch 21/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1278 - val_loss: 0.3132
# Epoch 22/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1272 - val_loss: 0.3115
# Epoch 23/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1267 - val_loss: 0.3113
# Epoch 24/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1265 - val_loss: 0.3117
# Epoch 25/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1261 - val_loss: 0.3092
# Epoch 26/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1257 - val_loss: 0.3077
# Epoch 27/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1255 - val_loss: 0.3080
# Epoch 28/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1251 - val_loss: 0.3087
# Epoch 29/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1247 - val_loss: 0.3087
# Epoch 30/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1244 - val_loss: 0.3081
# Epoch 31/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1240 - val_loss: 0.3096
# Epoch 32/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1239 - val_loss: 0.3094
# Epoch 33/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1231 - val_loss: 0.3056
# Epoch 34/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1233 - val_loss: 0.3047
# Epoch 35/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1232 - val_loss: 0.3065
# Epoch 36/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1228 - val_loss: 0.3070
# Epoch 37/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1225 - val_loss: 0.3056
# Epoch 38/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1223 - val_loss: 0.3039
# Epoch 39/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1222 - val_loss: 0.3030
# Epoch 40/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1220 - val_loss: 0.3038
# Epoch 41/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1220 - val_loss: 0.3049
# Epoch 42/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1217 - val_loss: 0.3052
# Epoch 43/200
# 2/2 [==============================] - 0s 28ms/step - loss: 0.1213 - val_loss: 0.3036
# Epoch 44/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1211 - val_loss: 0.3023
# Epoch 45/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1214 - val_loss: 0.3033
# Epoch 46/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1213 - val_loss: 0.3058
# Epoch 47/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1211 - val_loss: 0.3064
# Epoch 48/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1209 - val_loss: 0.3055
# Epoch 49/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1207 - val_loss: 0.3059
# Epoch 50/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1207 - val_loss: 0.3067
# Epoch 51/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1206 - val_loss: 0.3057
# Epoch 52/200
# 2/2 [==============================] - 0s 29ms/step - loss: 0.1204 - val_loss: 0.3042
# Epoch 53/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1205 - val_loss: 0.3038
# Epoch 54/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1204 - val_loss: 0.3043
# Epoch 55/200
# 2/2 [==============================] - 0s 55ms/step - loss: 0.1202 - val_loss: 0.3043
# Epoch 56/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1200 - val_loss: 0.3049
# Epoch 57/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1202 - val_loss: 0.3064
# Epoch 58/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1202 - val_loss: 0.3061
# Epoch 59/200
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1198 - val_loss: 0.3044
# Epoch 60/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1198 - val_loss: 0.3043
# Epoch 61/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1198 - val_loss: 0.3052
# Epoch 62/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1196 - val_loss: 0.3063
# Epoch 63/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1193 - val_loss: 0.3053
# Epoch 64/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1194 - val_loss: 0.3057
# Epoch 65/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1194 - val_loss: 0.3069
# Epoch 66/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1192 - val_loss: 0.3059
# Epoch 67/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1192 - val_loss: 0.3061
# Epoch 68/200
# 2/2 [==============================] - 0s 64ms/step - loss: 0.1192 - val_loss: 0.3075
# Epoch 69/200
# 2/2 [==============================] - 0s 53ms/step - loss: 0.1190 - val_loss: 0.3066
# Epoch 70/200
# 2/2 [==============================] - 0s 58ms/step - loss: 0.1186 - val_loss: 0.3055
# Epoch 71/200
# 2/2 [==============================] - 0s 223ms/step - loss: 0.1189 - val_loss: 0.3057
# Epoch 72/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1188 - val_loss: 0.3065
# Epoch 73/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1186 - val_loss: 0.3065
# Epoch 74/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1185 - val_loss: 0.3066
# Epoch 75/200
# 2/2 [==============================] - 0s 43ms/step - loss: 0.1185 - val_loss: 0.3069
# Epoch 76/200
# 2/2 [==============================] - 0s 190ms/step - loss: 0.1184 - val_loss: 0.3077
# Epoch 77/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1183 - val_loss: 0.3081
# Epoch 78/200
# 2/2 [==============================] - 0s 67ms/step - loss: 0.1181 - val_loss: 0.3075
# Epoch 79/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1179 - val_loss: 0.3071
# Epoch 80/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1179 - val_loss: 0.3072
# Epoch 81/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1180 - val_loss: 0.3076
# Epoch 82/200
# 2/2 [==============================] - 0s 153ms/step - loss: 0.1178 - val_loss: 0.3088
# Epoch 83/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1177 - val_loss: 0.3084
# Epoch 84/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1176 - val_loss: 0.3085
# Epoch 85/200
# 2/2 [==============================] - 0s 192ms/step - loss: 0.1177 - val_loss: 0.3093
# Epoch 86/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1174 - val_loss: 0.3099
# Epoch 87/200
# 2/2 [==============================] - 0s 167ms/step - loss: 0.1174 - val_loss: 0.3096
# Epoch 88/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1173 - val_loss: 0.3097
# Epoch 89/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1172 - val_loss: 0.3110
# Epoch 90/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1170 - val_loss: 0.3101
# Epoch 91/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1169 - val_loss: 0.3089
# Epoch 92/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1169 - val_loss: 0.3092
# Epoch 93/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1169 - val_loss: 0.3102
# Epoch 94/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1167 - val_loss: 0.3101
# Epoch 95/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1166 - val_loss: 0.3091
# Epoch 96/200
# 2/2 [==============================] - 0s 70ms/step - loss: 0.1165 - val_loss: 0.3097
# Epoch 97/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1165 - val_loss: 0.3112
# Epoch 98/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1162 - val_loss: 0.3097
# Epoch 99/200
# 2/2 [==============================] - 0s 84ms/step - loss: 0.1160 - val_loss: 0.3101
# Epoch 100/200
# 2/2 [==============================] - 0s 111ms/step - loss: 0.1161 - val_loss: 0.3110
# Epoch 101/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1160 - val_loss: 0.3122
# Epoch 102/200
# 2/2 [==============================] - 0s 201ms/step - loss: 0.1158 - val_loss: 0.3128
# Epoch 103/200
# 2/2 [==============================] - 0s 181ms/step - loss: 0.1157 - val_loss: 0.3126
# Epoch 104/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1154 - val_loss: 0.3123
# Epoch 105/200
# 2/2 [==============================] - 0s 149ms/step - loss: 0.1157 - val_loss: 0.3123
# Epoch 106/200
# 2/2 [==============================] - 0s 52ms/step - loss: 0.1154 - val_loss: 0.3127
# Epoch 107/200
# 2/2 [==============================] - 0s 110ms/step - loss: 0.1150 - val_loss: 0.3124
# Epoch 108/200
# 2/2 [==============================] - 0s 147ms/step - loss: 0.1151 - val_loss: 0.3122
# Epoch 109/200
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1149 - val_loss: 0.3123
# Epoch 110/200
# 2/2 [==============================] - 0s 76ms/step - loss: 0.1148 - val_loss: 0.3127
# Epoch 111/200
# 2/2 [==============================] - 0s 119ms/step - loss: 0.1147 - val_loss: 0.3135
# Epoch 112/200
# 2/2 [==============================] - 0s 205ms/step - loss: 0.1146 - val_loss: 0.3136
# Epoch 113/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1142 - val_loss: 0.3136
# Epoch 114/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1142 - val_loss: 0.3142
# Epoch 115/200
# 2/2 [==============================] - 0s 65ms/step - loss: 0.1141 - val_loss: 0.3145
# Epoch 116/200
# 2/2 [==============================] - 0s 154ms/step - loss: 0.1140 - val_loss: 0.3148
# Epoch 117/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1139 - val_loss: 0.3152
# Epoch 118/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1137 - val_loss: 0.3154
# Epoch 119/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1136 - val_loss: 0.3158
# Epoch 120/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1134 - val_loss: 0.3163
# Epoch 121/200
# 2/2 [==============================] - 0s 100ms/step - loss: 0.1134 - val_loss: 0.3163
# Epoch 122/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1132 - val_loss: 0.3162
# Epoch 123/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1130 - val_loss: 0.3163
# Epoch 124/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1128 - val_loss: 0.3165
# Epoch 125/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1127 - val_loss: 0.3170
# Epoch 126/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1125 - val_loss: 0.3170
# Epoch 127/200
# 2/2 [==============================] - 0s 77ms/step - loss: 0.1125 - val_loss: 0.3173
# Epoch 128/200
# 2/2 [==============================] - 0s 205ms/step - loss: 0.1125 - val_loss: 0.3176
# Epoch 129/200
# 2/2 [==============================] - 0s 54ms/step - loss: 0.1122 - val_loss: 0.3175
# Epoch 130/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1120 - val_loss: 0.3172
# Epoch 131/200
# 2/2 [==============================] - 0s 49ms/step - loss: 0.1121 - val_loss: 0.3176
# Epoch 132/200
# 2/2 [==============================] - 0s 68ms/step - loss: 0.1118 - val_loss: 0.3176
# Epoch 133/200
# 2/2 [==============================] - 0s 66ms/step - loss: 0.1116 - val_loss: 0.3181
# Epoch 134/200
# 2/2 [==============================] - 0s 141ms/step - loss: 0.1115 - val_loss: 0.3186
# Epoch 135/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1111 - val_loss: 0.3189
# Epoch 136/200
# 2/2 [==============================] - 0s 69ms/step - loss: 0.1111 - val_loss: 0.3196
# Epoch 137/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1110 - val_loss: 0.3201
# Epoch 138/200
# 2/2 [==============================] - 0s 74ms/step - loss: 0.1106 - val_loss: 0.3197
# Epoch 139/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1108 - val_loss: 0.3195
# Epoch 140/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1104 - val_loss: 0.3187
# Epoch 141/200
# 2/2 [==============================] - 0s 62ms/step - loss: 0.1103 - val_loss: 0.3192
# Epoch 142/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1103 - val_loss: 0.3185
# Epoch 143/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1097 - val_loss: 0.3175
# Epoch 144/200
# 2/2 [==============================] - 0s 61ms/step - loss: 0.1102 - val_loss: 0.3178
# Epoch 145/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1099 - val_loss: 0.3188
# Epoch 146/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1096 - val_loss: 0.3197
# Epoch 147/200
# 2/2 [==============================] - 0s 46ms/step - loss: 0.1093 - val_loss: 0.3200
# Epoch 148/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1092 - val_loss: 0.3204
# Epoch 149/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1090 - val_loss: 0.3210
# Epoch 150/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1087 - val_loss: 0.3203
# Epoch 151/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1085 - val_loss: 0.3200
# Epoch 152/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1086 - val_loss: 0.3200
# Epoch 153/200
# 2/2 [==============================] - 0s 175ms/step - loss: 0.1084 - val_loss: 0.3195
# Epoch 154/200
# 2/2 [==============================] - 0s 80ms/step - loss: 0.1081 - val_loss: 0.3186
# Epoch 155/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1082 - val_loss: 0.3194
# Epoch 156/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1082 - val_loss: 0.3195
# Epoch 157/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1078 - val_loss: 0.3195
# Epoch 158/200
# 2/2 [==============================] - 0s 63ms/step - loss: 0.1076 - val_loss: 0.3188
# Epoch 159/200
# 2/2 [==============================] - 0s 48ms/step - loss: 0.1074 - val_loss: 0.3178
# Epoch 160/200
# 2/2 [==============================] - 0s 57ms/step - loss: 0.1072 - val_loss: 0.3174
# Epoch 161/200
# 2/2 [==============================] - 0s 82ms/step - loss: 0.1072 - val_loss: 0.3174
# Epoch 162/200
# 2/2 [==============================] - 0s 83ms/step - loss: 0.1070 - val_loss: 0.3180
# Epoch 163/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1067 - val_loss: 0.3180
# Epoch 164/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1067 - val_loss: 0.3178
# Epoch 165/200
# 2/2 [==============================] - 0s 51ms/step - loss: 0.1065 - val_loss: 0.3186
# Epoch 166/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1066 - val_loss: 0.3182
# Epoch 167/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1061 - val_loss: 0.3175
# Epoch 168/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1061 - val_loss: 0.3176
# Epoch 169/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1061 - val_loss: 0.3187
# Epoch 170/200
# 2/2 [==============================] - 0s 39ms/step - loss: 0.1055 - val_loss: 0.3169
# Epoch 171/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1055 - val_loss: 0.3190
# Epoch 172/200
# 2/2 [==============================] - 0s 45ms/step - loss: 0.1056 - val_loss: 0.3190
# Epoch 173/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1052 - val_loss: 0.3175
# Epoch 174/200
# 2/2 [==============================] - 0s 36ms/step - loss: 0.1048 - val_loss: 0.3165
# Epoch 175/200
# 2/2 [==============================] - 0s 31ms/step - loss: 0.1053 - val_loss: 0.3172
# Epoch 176/200
# 2/2 [==============================] - 0s 35ms/step - loss: 0.1052 - val_loss: 0.3173
# Epoch 177/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1048 - val_loss: 0.3176
# Epoch 178/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1045 - val_loss: 0.3188
# Epoch 179/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1044 - val_loss: 0.3194
# Epoch 180/200
# 2/2 [==============================] - 0s 30ms/step - loss: 0.1043 - val_loss: 0.3198
# Epoch 181/200
# 2/2 [==============================] - 0s 40ms/step - loss: 0.1038 - val_loss: 0.3199
# Epoch 182/200
# 2/2 [==============================] - 0s 47ms/step - loss: 0.1044 - val_loss: 0.3209
# Epoch 183/200
# 2/2 [==============================] - 0s 73ms/step - loss: 0.1039 - val_loss: 0.3213
# Epoch 184/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1032 - val_loss: 0.3206
# Epoch 185/200
# 2/2 [==============================] - 0s 44ms/step - loss: 0.1047 - val_loss: 0.3213
# Epoch 186/200
# 2/2 [==============================] - 0s 33ms/step - loss: 0.1045 - val_loss: 0.3225
# Epoch 187/200
# 2/2 [==============================] - 0s 27ms/step - loss: 0.1049 - val_loss: 0.3202
# Epoch 188/200
# 2/2 [==============================] - 0s 56ms/step - loss: 0.1034 - val_loss: 0.3176
# Epoch 189/200
# 2/2 [==============================] - 0s 38ms/step - loss: 0.1050 - val_loss: 0.3179
# Epoch 190/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1035 - val_loss: 0.3257
# Epoch 191/200
# 2/2 [==============================] - 0s 32ms/step - loss: 0.1045 - val_loss: 0.3251
# Epoch 192/200
# 2/2 [==============================] - 0s 41ms/step - loss: 0.1030 - val_loss: 0.3211
# Epoch 193/200
# 2/2 [==============================] - 0s 112ms/step - loss: 0.1031 - val_loss: 0.3213
# Epoch 194/200
# 2/2 [==============================] - 0s 59ms/step - loss: 0.1033 - val_loss: 0.3246
# Epoch 195/200
# 2/2 [==============================] - 0s 50ms/step - loss: 0.1028 - val_loss: 0.3243
# Epoch 196/200
# 2/2 [==============================] - 0s 37ms/step - loss: 0.1020 - val_loss: 0.3223
# Epoch 197/200
# 2/2 [==============================] - 0s 42ms/step - loss: 0.1025 - val_loss: 0.3244
# Epoch 198/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1019 - val_loss: 0.3230
# Epoch 199/200
# 2/2 [==============================] - 0s 60ms/step - loss: 0.1018 - val_loss: 0.3263
# Epoch 200/200
# 2/2 [==============================] - 0s 34ms/step - loss: 0.1020 - val_loss: 0.3258

# %%
"""
Model Evaluation
"""

test_pred = model.predict(testX)
train_pred = model.predict(trainX)

print("Goodness of Fit of Model \tTrain Dataset")
print("RMSE \t\t\t\t:", math.sqrt(mean_squared_error(trainY, train_pred)))
print()

print("Goodness of Fit of Model \tTest Dataset")
print("RMSE \t\t\t\t:", math.sqrt(mean_squared_error(testY, test_pred)))
print()
# Out:
# WARNING:tensorflow:AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fb2262aaef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function Model.make_predict_function.<locals>.predict_function at 0x7fb2262aaef0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: 'arguments' object has no attribute 'posonlyargs'
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Goodness of Fit of Model 	Train Dataset
# RMSE 				: 0.22057846994347177
#
# Goodness of Fit of Model 	Test Dataset
# RMSE 				: 0.4773711478877735

# %%
"""
Visualize model performance (predicted vs actual)
"""

pyplot.figure(figsize=(20,8))
pyplot.plot(test_pred[:500], label='predict')
pyplot.plot(testY[:500], label='actual')

pyplot.ylabel('Relative quantity of ingredients to order', size=15)
pyplot.xlabel('Time step', size=15)
pyplot.legend(loc='upper right',fontsize=15)

pyplot.show()

# %%
"""
Visualize model performance (model loss)
"""

pyplot.figure(figsize=(20,8))
pyplot.plot(history.history['loss'], label='train')
pyplot.plot(history.history['val_loss'], label='validation')

pyplot.ylabel('model loss',size=15)
pyplot.xlabel('epochs',size=15)
pyplot.legend(loc='upper right',fontsize=15)

pyplot.show()

# %% [markdown]
# ## Prescriptive Analytics
#
# Given the historical demand of each ingredient, along with the necessary information of statistics such as the pricing and costing of each ingredient, we will generate a stochastic model to optimize the quantity of ingredients to be imported and ordered by Salad Stop as well as the subsequent expected amount of profits to be earned by salad stop. We will then test our stochastic model with the forecasted demand generated by our neural network. This problem is similar to the multiple items newsvendor problem, hence our stochastic model will be greatly based on it.
#
# #### Stochastic Model:
#
# $$
# \begin{align*}
# \max \ &\sum_{i = 1}^N\left( \frac{1}{K} \sum_{k = 1}^K p_i t_{ki} - c_i x_i \right) \\
# {\rm s.t.}\  & t_{ki} \leq x_i & \forall i = 1,...,N, k = 1,...,K\\
# &t_{ki} \leq d_{ki} & \forall i = 1,...,N, k = i,...,K\\
# &\sum_{i = 1}^N s_i x_i \leq C\\
# &x_i \geq 0 & \forall i = 1,...,N
# \end{align*}
# $$

# %%
"""
Data preparation
"""

Demand_data = pd.read_csv("demand_menu.csv")
d = Demand_data.set_index('Date').T
d
# Out:
# Date    Red & White Cabbage  Romaine  Kale  Baby Spinach  Wholemeal Wrap  \
# 1/1/22                   41        2    48            53              34
# 2/1/22                   78       58    30            43              69
# 3/1/22                   80       18    74            96              29
# 4/1/22                   57        7    97            16              44
# 5/1/22                   90       66    98            24             100
# 6/1/22                   72       59    25            91              51
# 7/1/22                   50        9    74            78              64
#
# Date    Spinach Wrap  Tortilla Wrap  Tomato Wrap  Cauliflower Rice  Quinoa  \
# 1/1/22            96             10           52                92      81
# 2/1/22            66             88           15                96      64
# 3/1/22             2             45           37                38      88
# 4/1/22            61             95           31                36      85
# 5/1/22            38             24           99                92      12
# 6/1/22            65             35           18                58      19
# 7/1/22            45             96            4                25      95
#
# Date    ...  Cashew Mint  Classic Caesar  Honey Dijon  Lemon & Oil  \
# 1/1/22  ...           10              40           36           53
# 2/1/22  ...           45              21           60           69
# 3/1/22  ...           75              43            4           37
# 4/1/22  ...           14              89           81           65
# 5/1/22  ...           99              54           94           87
# 6/1/22  ...           30               2           24           24
# 7/1/22  ...           16              45           34            7
#
# Date    Mixed Berries Vinaigrette  Olive Oil  Salt & Pepper  Smoked Pimento  \
# 1/1/22                         33         64             61              25
# 2/1/22                         36         40              1              93
# 3/1/22                         44          3             30              77
# 4/1/22                         15         29             14              70
# 5/1/22                         99         57             38               5
# 6/1/22                         81         38             40              34
# 7/1/22                         35          2             29              46
#
# Date    Smoky Ranch  Tabbasco Sauce
# 1/1/22            1              53
# 2/1/22           26               5
# 3/1/22           75              83
# 4/1/22           14               8
# 5/1/22           86              61
# 6/1/22           71              36
# 7/1/22           29              20
#
# [7 rows x 87 columns]

# %%
"""
Assignment of pricing to our dataset

9.9: 2 Dressing + 7 Ingredient + 1 Standard Base
11.9: 2 Dressing + 7 Ingredient + 1 Premium Base

Assume that the price of each element is constant, hence:
1 Dressing: 0.99
1 Ingredient: 0.99
1 Standard Base: 0.99

Then Premium base would be the cost of standard base + the difference between premium base and standard base, hence:
1 Premium Base: 2.99
"""

Param_data = pd.DataFrame().assign(Ingredient=data1['Ingredient'], COGS=data1['COGS_per_serving'], Ingredient_Type=data1['Ingredient_type'], Additional_Price_For_Premium_Toppings=data1['Price'])
Param_data['Price'] = None
Param_data['Space'] = None

for i in range(Param_data.shape[0]):
    if Param_data["Ingredient_Type"][i] in ["Standard Base", "Wrap", "Grain Bowl", "Standard Topping", "Dressing (Western)", "Dressing (Asian)"]:
        Param_data["Price"][i] = 0.99
    elif Param_data["Ingredient_Type"][i] in ["Premium Base"]:
        Param_data["Price"][i] = 2.99
    elif Param_data["Ingredient_Type"][i] in ["Premium Topping"]:
        Param_data["Price"][i] = Param_data["Additional_Price_For_Premium_Toppings"][i]
    
    Param_data["Space"][i] = round(random.uniform(0, 1), 2)
        
Param_data = Param_data.set_index('Ingredient').T
Param_data
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:28: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:24: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# Ingredient                            Red & White Cabbage        Romaine  \
# COGS                                                 0.53           1.86
# Ingredient_Type                             Standard Base  Standard Base
# Additional_Price_For_Premium_Toppings                 NaN            NaN
# Price                                                0.99           0.99
# Space                                                0.88           0.16
#
# Ingredient                                     Kale  Baby Spinach  \
# COGS                                           3.75          0.56
# Ingredient_Type                        Premium Base  Premium Base
# Additional_Price_For_Premium_Toppings           NaN           NaN
# Price                                          2.99          2.99
# Space                                          0.18          0.99
#
# Ingredient                            Wholemeal Wrap Spinach Wrap  \
# COGS                                            0.99          1.4
# Ingredient_Type                                 Wrap         Wrap
# Additional_Price_For_Premium_Toppings            NaN          NaN
# Price                                           0.99         0.99
# Space                                           0.14         0.21
#
# Ingredient                            Tortilla Wrap Tomato Wrap  \
# COGS                                           0.79        0.67
# Ingredient_Type                                Wrap        Wrap
# Additional_Price_For_Premium_Toppings           NaN         NaN
# Price                                          0.99        0.99
# Space                                          0.92         0.5
#
# Ingredient                            Cauliflower Rice      Quinoa  ...  \
# COGS                                              1.47        1.01  ...
# Ingredient_Type                             Grain Bowl  Grain Bowl  ...
# Additional_Price_For_Premium_Toppings              NaN         NaN  ...
# Price                                             0.99        0.99  ...
# Space                                             0.77        0.97  ...
#
# Ingredient                                 Classic Caesar         Honey Dijon  \
# COGS                                                 0.83                0.75
# Ingredient_Type                        Dressing (Western)  Dressing (Western)
# Additional_Price_For_Premium_Toppings                 NaN                 NaN
# Price                                                0.99                0.99
# Space                                                0.56                0.12
#
# Ingredient                                    Lemon & Oil  \
# COGS                                                 1.19
# Ingredient_Type                        Dressing (Western)
# Additional_Price_For_Premium_Toppings                 NaN
# Price                                                0.99
# Space                                                0.95
#
# Ingredient                            Mixed Berries Vinaigrette  \
# COGS                                                       0.75
# Ingredient_Type                              Dressing (Western)
# Additional_Price_For_Premium_Toppings                       NaN
# Price                                                      0.99
# Space                                                      0.17
#
# Ingredient                                      Olive Oil       Salt & Pepper  \
# COGS                                                 0.34                0.29
# Ingredient_Type                        Dressing (Western)  Dressing (Western)
# Additional_Price_For_Premium_Toppings                 NaN                 NaN
# Price                                                0.99                0.99
# Space                                                 0.5                0.62
#
# Ingredient                                 Smoked Pimento         Smoky Ranch  \
# COGS                                                 1.07                0.85
# Ingredient_Type                        Dressing (Western)  Dressing (Western)
# Additional_Price_For_Premium_Toppings                 NaN                 NaN
# Price                                                0.99                0.99
# Space                                                0.66                0.84
#
# Ingredient                                 Tabbasco Sauce  Placeholder
# COGS                                                 0.25            0
# Ingredient_Type                        Dressing (Western)  Placeholder
# Additional_Price_For_Premium_Toppings                 NaN          NaN
# Price                                                0.99         None
# Space                                                 0.7         0.08
#
# [5 rows x 88 columns]

# %%
demand = np.array(d.values[:,0:d.shape[1]].astype(int))
price = np.array(Param_data.values[4,0:d.shape[1]].astype(np.float64))
cost = np.array(Param_data.values[0,0:d.shape[1]].astype(np.float64))
space = np.array(Param_data.values[3,0:d.shape[1]].astype(np.float64))
total_space = 1000

# %%
"""
Generate quantities of ingredients to import by Salad Stop and the expected amount of profits:
"""

def generate_quantities_and_expected_profits(ingredient_pricing, ingredient_costing, customer_demand, ingredient_spacing, store_space):
    
    '''
    Construct Optimizer.
    '''
    model = ro.Model('Ingredient Order Optimizer Model')
    
    '''
    Other variables to be used later:
    '''
    number_of_days = customer_demand.shape[0]
    number_of_ingredients = customer_demand.shape[1]
    
    '''
    Initialize Decision Variables
    x is amount of ingredients to order
    t is the matrix of the amount of ingredients to order for each number of days in the dataset
    '''
    x = model.dvar(number_of_ingredients)
    t = model.dvar((number_of_days, number_of_ingredients))
    
    '''
    Objective function: Maximize the average profit to be earned by Salad Stop based on the number of ingredients to be ordered
    '''
    model.max(1/number_of_days*((t @ ingredient_pricing).sum()) - sum(x[i] * ingredient_costing[i] for i in range(number_of_ingredients)))
    
    '''
    Constraint 1: Constraint to linearize term min[px, pd] where px is the expected amount of quantity to order and pd is the expected amount of demand
    Reference: Newsvendor model formula
    '''
    model.st(t[:,i] <= x[i] for i in range(number_of_ingredients))
    
    '''
    Constraint 2: Ensure that the amount of ingredients to order for each day is less or equal to the expected demand 
    '''
    model.st(t <= customer_demand)
    
    '''
    Constraint 3: Ensure that the amount of ingredients to order for each day is less or equal than 
    '''
    model.st(ingredient_spacing @ x <= store_space)
    
    '''
    Constraint 4: Ensure that the amount of ingredients to order is at least 5 per day in case an arbitrary customer wishes to order an unpopular/uncommon ingredient
    '''
    model.st(x >= 0)
    
    '''
    Solve the model and generate results
    '''
    model.solve(grb, display = True)
    
    return x.get(), model.get()

# %%
expected_amount_of_orders, expected_amount_of_profit = generate_quantities_and_expected_profits(price, cost, demand, space, total_space)
print('Expected profit is:', expected_amount_of_profit)
print()
expected_amount_of_orders_df = pd.DataFrame().assign(Ingredient=list(data1['Ingredient'])[:-1], Quantity_to_order=expected_amount_of_orders)
expected_amount_of_orders_df.set_index("Ingredient").T
# Out:
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0042s
# Expected profit is: 355.32917748917754
# Ingredient         Red & White Cabbage  Romaine  Kale  Baby Spinach  \
# Quantity_to_order                 50.0      0.0   0.0           0.0
#
# Ingredient         Wholemeal Wrap  Spinach Wrap  Tortilla Wrap  Tomato Wrap  \
# Quantity_to_order             0.0           0.0            0.0          0.0
#
# Ingredient         Cauliflower Rice  Quinoa  ...  Cashew Mint  Classic Caesar  \
# Quantity_to_order               0.0     0.0  ...          0.0             0.0
#
# Ingredient         Honey Dijon  Lemon & Oil  Mixed Berries Vinaigrette  \
# Quantity_to_order          0.0          0.0                        0.0
#
# Ingredient         Olive Oil  Salt & Pepper  Smoked Pimento  Smoky Ranch  \
# Quantity_to_order        2.0           29.0             0.0          0.0
#
# Ingredient         Tabbasco Sauce
# Quantity_to_order            20.0
#
# [1 rows x 87 columns]

# %%
x_volume_of_space = []
y_profit = []

for i in range(0, 3000, 500):
    x_volume_of_space.append(i)
    expected_amount_of_orders, expected_amount_of_profit = generate_quantities_and_expected_profits(price, cost, demand, space, i)
    y_profit.append(expected_amount_of_profit)
# Out:
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0012s
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0044s
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0056s
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0039s
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0015s
# Being solved by Gurobi...
# Solution status: 2
# Running time: 0.0027s

# %%
fig = plt.figure()
fig.set_size_inches(20, 5)
ax = fig.add_axes([0,0,1,1])
ax.set_ylabel('Amount of profit')
ax.set_xlabel('Volume of space')
x = x_volume_of_space
y = y_profit
ax.plot(x,y)
plt.show()
